# %%
import numpy as np 
import pandas as pd 
import sys 
sys.path.insert(1, '/its/home/drs25/Robot_foot/')
from Robot_foot import opticalSensor, ImageDataPreprocessor
import matplotlib.pyplot as plt

# %% [markdown]
# ## prep

# %%
# load in data set
XB=np.load("/mnt/data0/drs25/data/optical-tactile-dataset-for-textures/3DPrintedbambu.npy")
datasetB=pd.read_csv("/its/home/drs25/3D-textures/Experimental/data/metagelbambu.csv")
XC=np.load("/mnt/data0/drs25/data/optical-tactile-dataset-for-textures/3DPrintedcreality.npy")
datasetC=pd.read_csv("/its/home/drs25/3D-textures/Experimental/data/metagelcreality.csv")
print(XB.shape,XC.shape)
#sort into prints and position
datasetB#['Pattern'].unique()
datasetC
# Out:
# (1900, 1, 192, 256) (1800, 1, 192, 256)
#       Unnamed: 0   Index Filament Pattern Printer Pressure
# 0              0     0.0  PLAplus    z1.5   ender      P30
# 1              1     1.0  PLAplus    z1.5   ender      P30
# 2              2     2.0  PLAplus    z1.5   ender      P30
# 3              3     3.0  PLAplus    z1.5   ender      P30
# 4              4     4.0  PLAplus    z1.5   ender      P30
# ...          ...     ...      ...     ...     ...      ...
# 1795        1795  1795.0  PLAplus    z5.3   ender      P30
# 1796        1796  1796.0  PLAplus    z5.3   ender      P30
# 1797        1797  1797.0  PLAplus    z5.3   ender      P30
# 1798        1798  1798.0  PLAplus    z5.3   ender      P30
# 1799        1799  1799.0  PLAplus    z5.3   ender      P30
#
# [1800 rows x 6 columns]

# %% [markdown]
# ## visualise

# %%
# convert image to marker position 
tactip = opticalSensor()
processor=ImageDataPreprocessor()
image=XB[0][0]
#image = np.dot(image[..., :3], [0.299, 0.587, 0.114]) #greyscale
plt.imshow(image,cmap="gray")
plt.show()
image=processor.process_raw_image(image)
plt.imshow(image)
plt.show()
coord=tactip.predict_points(image.reshape((1,-1))) #preduct points
#check it is accurate
# Out:
# /its/home/drs25/Robot_foot/Robot_foot/__init__.py:91: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# Convertall classes and plot them in different colours for each class, look at clusters

# %%
# Convertall classes and plot them all averaged in different colours for each class, look at clusters

# %% [markdown]
# ## qualitative

# %%
# get MSE for all
